# %% [markdown]
# ## Entrar no Rewards ##

# %%
import pyautogui
import time 
import pyperclip
import random

# =====================
# Entrar no REWARDS
# =====================

pyautogui.press("win")
time.sleep(1.5)
#muda para o teu navegador!
pyautogui.write("brave")
time.sleep(2)
pyautogui.press("enter")
time.sleep(1.5)
pyautogui.write("https://rewards.bing.com")
pyautogui.press("enter")

# %% [markdown]
# ## Resgatar Diaria ##

# %%
import pyautogui
import time 
import pyperclip
import random

# =====================
# Resgatar CONJUNTO DIÁRIO
# =====================

time.sleep(5)

pyautogui.click(x=450, y=450)
time.sleep(1)
pyautogui.scroll(-300)
time.sleep(1)
pyautogui.click(x=550, y=600)
time.sleep(1)
pyautogui.click(x=100, y=18)
time.sleep(1)
pyautogui.click(x=1150,y=650)
time.sleep(1)
pyautogui.click(x=100, y=18)
time.sleep(1)
pyautogui.click(x=1550,y=650)

# %% [markdown]
# ## Pesquisa Diaria ##

# %%
import pyautogui
import time 
import pyperclip
import random

termo = random.choice(pesquisas)
numero = random.randint(1, 100)

pyautogui.write(f"{termo} {numero}")

pesquisas = [
    "Star Wars",
    "Harry Potter",
    "Avatar",
    "Hobbit",
    "Senhor dos Aneis",
    "Homem-Aranha"
]

# =====================
# Resgatar PONTOS COM PESQUISA
# =====================

# =====================
# Escrever no local do clique

pyautogui.sleep(3)

pyautogui.click(x= 264, y = 22) 
pyautogui.click(x= 600, y= 60)
pyautogui.write("https://www.bing.com/?FORM=Z9FD1")
pyautogui.sleep(1)
pyautogui.hotkey('enter')

# =====================
# Escrever, começo

pyautogui.sleep(2)
pyautogui.click(x=880, y=325)
pyautogui.write("Nerdola")
pyautogui.sleep(1)
pyautogui.hotkey('enter')
pyautogui.sleep(1.5)

# =====================
# Escrever aleatoriamente
# =====================
for i in range(20):
    pyautogui.click(x=355, y=165)
    pyautogui.hotkey("ctrl", "a")  # seleciona tudo
    pyautogui.press("backspace")

    time.sleep(random.uniform(1, 2))
    pyautogui.write(f"{termo} {numero}")
    
    time.sleep(random.uniform(1, 2))
    pyautogui.press("enter")

    time.sleep(3)

# %%
for i in range(10):
    pyautogui.click(x=755, y=165)
    pyautogui.click[2](x=755, y=165)
    time.sleep(1)
    pyautogui.write(f"nerdoland{i+1}")
    time.sleep(1)
    pyautogui.click(x=606, y=162)
    time.sleep(1)
    pyautogui.click(x=559, y=22)
    time.sleep(2)

    time.sleep(3)
for i in range(11):
    pyautogui.click(x=755, y=165)
    pyautogui.click(x=755, y=165)
    pyautogui.click(x=755, y=165)
    pyautogui.press("backspace")
    time.sleep(1)
    pyautogui.write(f"Star Wars {i+1}")
    time.sleep(1)
    pyautogui.click(x=606, y=162)
    time.sleep(1)
    pyautogui.click(x=559, y=22)
    time.sleep(2)

for i in range(8):
    pyautogui.click(x=755, y=165)
    pyautogui.click(x=755, y=165)
    pyautogui.click(x=755, y=165)
    pyautogui.press("backspace")
    time.sleep(1)
    pyautogui.write(f"Harry Potter {i+1}")
    time.sleep(1)
    pyautogui.click(x=606, y=162)
    time.sleep(1)
    pyautogui.click(x=559, y=22)
    time.sleep(2)
 
for i in range(3):
    pyautogui.click(x=755, y=165)
    pyautogui.click(x=755, y=165)
    pyautogui.click(x=755, y=165)
    pyautogui.press("backspace")
    time.sleep(1)
    pyautogui.write(f"Senhor dos Aneis {i+1}")
    time.sleep(1)
    pyautogui.click(x=606, y=162)
    time.sleep(1)
    pyautogui.click(x=559, y=22)
    time.sleep(2)

for i in range(3):
    pyautogui.click(x=755, y=165)
    pyautogui.click(x=755, y=165)
    pyautogui.click(x=755, y=165)
    pyautogui.press("backspace")
    time.sleep(1)
    pyautogui.write(f"Hobbit {i+1}")
    time.sleep(1)
    pyautogui.click(x=606, y=162)
    time.sleep(1)
    pyautogui.click(x=559, y=22)
    time.sleep(2)

for i in range(3):
    pyautogui.click(x=755, y=165)
    pyautogui.click(x=755, y=165)
    pyautogui.click(x=755, y=165)
    pyautogui.press("backspace")
    time.sleep(1)
    pyautogui.write(f"Avatar {i+1}")
    time.sleep(1)
    pyautogui.click(x=606, y=162)
    time.sleep(1)
    pyautogui.click(x=559, y=22)
    time.sleep(2)

for i in range(2):
    pyautogui.click(x=755, y=165)
    pyautogui.click(x=755, y=165)
    pyautogui.click(x=755, y=165)
    pyautogui.press("backspace")
    time.sleep(1)
    pyautogui.write(f"Homem-Aranha {i+1}")
    time.sleep(1)
    pyautogui.click(x=606, y=162)
    time.sleep(1)
    pyautogui.click(x=559, y=22)
    time.sleep(2)
